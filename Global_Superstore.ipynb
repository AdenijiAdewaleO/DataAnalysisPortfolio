# %% [markdown]
# # LAB 1: EXPLORING THE GLOBAL SUPERSTORE DATASET

# %%
#import some useful libraries

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## LOAD DATASET AND PERFORM EXPLORATORY DATA ANALYSIS
#
# Our dataset is the Global Superstore data and we will be loading the dataset into a pandas dataframe after which we will perform some exploratory data analysis to see what the data is made up of and also tease out some initial insights.

# %%
# load data from csv
df = pd.read_excel("/content/drive/MyDrive/ADEWALE DATA ANALYSIS /Global Superstore.xls")
df
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
# Let's see what the columns look like in terms of the data it holds
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %% [markdown]
# > The dataset contains 51,290 entries and 24 columns. Of the 24 columns, only the 'Postal code' column has null values. We will leave the null values for now because entries with null values under 'Postal code' constitute more than 80% of the dataset. Also, the postal code may not be pertinent to our current analysis.
#
#
# > The above info summary about the dataset also reveals that there are 7 numeric variables, 15 categorical variables and 2 date variables. Of the 7 numeric variables, it has to be noted that numerical calculations such as sum and mean, when performed on Postal Code does not have a practical implication.

# %%
#Let's look at the statistical information for the numeric data.
df.describe().T
# Out:
#                  count          mean           std       min           25%  \
# Row ID         51290.0  25645.500000  14806.291990     1.000  12823.250000
# Postal Code     9994.0  55190.379428  32063.693350  1040.000  23223.000000
# Sales          51290.0    246.490581    487.565361     0.444     30.758625
# Quantity       51290.0      3.476545      2.278766     1.000      2.000000
# Discount       51290.0      0.142908      0.212280     0.000      0.000000
# Profit         51290.0     28.610982    174.340972 -6599.978      0.000000
# Shipping Cost  51290.0     26.375818     57.296810     0.002      2.610000
#
#                      50%         75%        max
# Row ID         25645.500  38467.7500  51290.000
# Postal Code    56430.500  90008.0000  99301.000
# Sales             85.053    251.0532  22638.480
# Quantity           3.000      5.0000     14.000
# Discount           0.000      0.2000      0.850
# Profit             9.240     36.8100   8399.976
# ...

# %% [markdown]
# From the above statistical description of the data, we see that the profit column has negative values (min of -6599.978). This means that some of the transactions made lossess (negative profits). Our analysis here is therefore to find out how the transactions fare in losses against the total sales.

# %% [markdown]
# ## AN INTERESTING GRAPH
#
# For our one interesting graph, we look at the total sales and profits by country.

# %%
#Group the dataset by country and sum the profits and sales for each country
country_profits = df.groupby('Country').sum()['Profit']
country_sales = df.groupby('Country').sum()['Sales']

# %%
country_df = pd.merge(country_profits, country_sales, on='Country', how='inner')
country_df.reset_index(inplace=True)

# %%
country_df.sort_values(by='Profit', ascending=True, inplace=True)
country_viz = country_df.head(20)
country_viz
# Out:
#                 Country       Profit         Sales
# 133              Turkey -98447.23200  108507.94800
# 94              Nigeria -80750.71800   54350.35200
# 90          Netherlands -41070.07500   77514.94500
# 54             Honduras -29482.37140   90125.64860
# 96             Pakistan -22446.64800   58872.61200
# 4             Argentina -18693.79672   57511.78328
# 97               Panama -17723.45248   51539.92752
# 123              Sweden -17519.36700   30491.40300
# 101         Philippines -16128.22500  183420.16500
# 117         South Korea -12792.83100   33125.37900
# 142           Venezuela -11222.71044   26587.82956
# 74            Lithuania  -8966.11800    6724.33200
# 103            Portugal  -8703.06000   15105.12000
# 35   Dominican Republic  -7613.49872  126140.58128
# 61              Ireland  -7392.38100   16639.50900
# 129            Thailand  -7308.19500   77051.95500
# 67           Kazakhstan  -7099.89600    4605.44400
# ...

# %%
# bar plot of sales and profit by country on the same axis

plt.bar(country_viz['Country'], country_viz.Sales, label='Sales')
plt.bar(country_viz['Country'], country_viz.Profit, label='Loss')
plt.xlabel('Country')
plt.xticks(rotation='vertical')
plt.title('Sales and Loss by top 20 countries with the most losses')
plt.legend()
plt.show()

# %% [markdown]
# ## RESULT ANALYSIS
# From the above bar graph, we can see how the losses made in the top 20 countries(rated by losses) compare with the total sales made in these countries. The following key points are highlighted:
#
# - Turkey has the highest total loss among all the countries
# - Countries like Nigeria, Lithuania, Kazakhstan and Zimbabwe are seen to have lossess that surpasses the total sales.
#
# There would need for further analysis to determine what are the contributing factors to the losses and why some countries have more losses than sales
